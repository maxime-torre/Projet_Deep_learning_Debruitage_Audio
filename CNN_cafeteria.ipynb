# %%
# CNN cafeteria

import torch
import librosa
import librosa.display
import numpy as np
import matplotlib.pyplot as plt
from IPython.display import Audio, display

print(f"torch.__version__ : {torch.__version__}")
# Out:
# torch.__version__ : 2.1.0+cpu

# %%
# 1. Charger un bruit de cafétaria 
y, sr = librosa.load(r"C:\Users\torre\Documents\Sicom 3A\Projet_Parole_Audio_SICOM_3A\LibriSpeech\dev-clean\84\121123\84-121123-0000.flac")

# %%
# Écouter le signal reconstruit
display(Audio(y, rate=sr))
# Out:
#                 <audio  controls="controls" >
#                     <source src="data:audio/wav;base64,..." type="audio/wav" />
#                     Your browser does not support the audio element.
#                 </audio>
